# %%
# %cd paddle_ocr/PaddleOCR/
# Out:
# /notebooks/paddle_ocr/PaddleOCR
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %% [markdown]
# ## Pretrained

# %% [markdown]
# ### PP-OCRv4

# %%
# !python tools/eval.py -c configs/rec/PP-OCRv4/PP-OCRv4_mobile_rec.yml \
  -o Eval.dataset.data_dir=../label_studio/rec \
     Eval.dataset.label_file_list='[../label_studio/rec/new_val.txt]'
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/07/14 03:30:01] ppocr WARNING: Skipping import of the encryption module.
# [2025/07/14 03:30:02] ppocr INFO: Architecture :
# [2025/07/14 03:30:02] ppocr INFO:     Backbone :
# [2025/07/14 03:30:02] ppocr INFO:         name : PPLCNetV3
# [2025/07/14 03:30:02] ppocr INFO:         scale : 0.95
# [2025/07/14 03:30:02] ppocr INFO:     Head :
# [2025/07/14 03:30:02] ppocr INFO:         head_list :
# [2025/07/14 03:30:02] ppocr INFO:             CTCHead :
# [2025/07/14 03:30:02] ppocr INFO:                 Head :
# [2025/07/14 03:30:02] ppocr INFO:                     fc_decay : 1e-05
# [2025/07/14 03:30:02] ppocr INFO:                 Neck :
# ...

# %%
# !python tools/eval.py -c configs/rec/PP-OCRv4/PP-OCRv4_mobile_rec.yml \
  -o Eval.dataset.data_dir=../label_studio/rec \
     Eval.dataset.label_file_list='[../label_studio/rec/new_val.txt]'
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/07/14 03:30:09] ppocr WARNING: Skipping import of the encryption module.
# [2025/07/14 03:30:09] ppocr INFO: Architecture :
# [2025/07/14 03:30:09] ppocr INFO:     Backbone :
# [2025/07/14 03:30:09] ppocr INFO:         name : PPLCNetV3
# [2025/07/14 03:30:09] ppocr INFO:         scale : 0.95
# [2025/07/14 03:30:09] ppocr INFO:     Head :
# [2025/07/14 03:30:09] ppocr INFO:         head_list :
# [2025/07/14 03:30:09] ppocr INFO:             CTCHead :
# [2025/07/14 03:30:09] ppocr INFO:                 Head :
# [2025/07/14 03:30:09] ppocr INFO:                     fc_decay : 1e-05
# [2025/07/14 03:30:09] ppocr INFO:                 Neck :
# ...

# %% [markdown]
# ### PP-OCRv5

# %%
# !python tools/eval.py -c configs/rec/PP-OCRv5/PP-OCRv5_mobile_rec.yml \
  -o Eval.dataset.data_dir=../label_studio/rec \
     Eval.dataset.label_file_list='[../label_studio/rec/new_train.txt]'
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/07/14 03:28:56] ppocr WARNING: Skipping import of the encryption module.
# [2025/07/14 03:28:56] ppocr INFO: Architecture :
# [2025/07/14 03:28:56] ppocr INFO:     Backbone :
# [2025/07/14 03:28:56] ppocr INFO:         name : PPLCNetV3
# [2025/07/14 03:28:56] ppocr INFO:         scale : 0.95
# [2025/07/14 03:28:56] ppocr INFO:     Head :
# [2025/07/14 03:28:56] ppocr INFO:         head_list :
# [2025/07/14 03:28:56] ppocr INFO:             CTCHead :
# [2025/07/14 03:28:56] ppocr INFO:                 Head :
# [2025/07/14 03:28:56] ppocr INFO:                     fc_decay : 1e-05
# [2025/07/14 03:28:56] ppocr INFO:                 Neck :
# ...

# %%
# !python tools/eval.py -c configs/rec/PP-OCRv5/PP-OCRv5_mobile_rec.yml \
  -o Eval.dataset.data_dir=../label_studio/rec \
     Eval.dataset.label_file_list='[../label_studio/rec/new_val.txt]'
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/07/14 03:28:47] ppocr WARNING: Skipping import of the encryption module.
# [2025/07/14 03:28:47] ppocr INFO: Architecture :
# [2025/07/14 03:28:47] ppocr INFO:     Backbone :
# [2025/07/14 03:28:47] ppocr INFO:         name : PPLCNetV3
# [2025/07/14 03:28:47] ppocr INFO:         scale : 0.95
# [2025/07/14 03:28:47] ppocr INFO:     Head :
# [2025/07/14 03:28:47] ppocr INFO:         head_list :
# [2025/07/14 03:28:47] ppocr INFO:             CTCHead :
# [2025/07/14 03:28:47] ppocr INFO:                 Head :
# [2025/07/14 03:28:47] ppocr INFO:                     fc_decay : 1e-05
# [2025/07/14 03:28:47] ppocr INFO:                 Neck :
# ...

# %% [markdown]
# ## Finetune PP-OCRv5

# %%
# !python tools/train.py -c configs/rec/PP-OCRv5/PP-OCRv5_mobile_rec.yml
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/07/10 03:42:29] ppocr WARNING: Skipping import of the encryption module.
# [2025/07/10 03:42:30] ppocr INFO: Architecture :
# [2025/07/10 03:42:30] ppocr INFO:     Backbone :
# [2025/07/10 03:42:30] ppocr INFO:         name : PPLCNetV3
# [2025/07/10 03:42:30] ppocr INFO:         scale : 0.95
# [2025/07/10 03:42:30] ppocr INFO:     Head :
# [2025/07/10 03:42:30] ppocr INFO:         head_list :
# [2025/07/10 03:42:30] ppocr INFO:             CTCHead :
# [2025/07/10 03:42:30] ppocr INFO:                 Head :
# [2025/07/10 03:42:30] ppocr INFO:                     fc_decay : 1e-05
# [2025/07/10 03:42:30] ppocr INFO:                 Neck :
# ...

# %% [markdown]
# ## Evaluate Finetuned Model

# %%
# !python tools/eval.py -c configs/rec/PP-OCRv5/PP-OCRv5_mobile_rec.yml \
  -o Global.pretrained_model=output/PP-OCRv5_mobile_rec/best_accuracy.pdparams \
     Eval.dataset.data_dir=../label_studio/rec \
     Eval.dataset.label_file_list='[../label_studio/rec/new_train.txt]'
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/07/14 03:28:21] ppocr WARNING: Skipping import of the encryption module.
# [2025/07/14 03:28:21] ppocr INFO: Architecture :
# [2025/07/14 03:28:21] ppocr INFO:     Backbone :
# [2025/07/14 03:28:21] ppocr INFO:         name : PPLCNetV3
# [2025/07/14 03:28:21] ppocr INFO:         scale : 0.95
# [2025/07/14 03:28:21] ppocr INFO:     Head :
# [2025/07/14 03:28:21] ppocr INFO:         head_list :
# [2025/07/14 03:28:21] ppocr INFO:             CTCHead :
# [2025/07/14 03:28:21] ppocr INFO:                 Head :
# [2025/07/14 03:28:21] ppocr INFO:                     fc_decay : 1e-05
# [2025/07/14 03:28:21] ppocr INFO:                 Neck :
# ...

# %%
# !python tools/eval.py -c configs/rec/PP-OCRv5/PP-OCRv5_mobile_rec.yml \
  -o Global.pretrained_model=output/PP-OCRv5_mobile_rec/best_accuracy.pdparams \
     Eval.dataset.data_dir=../label_studio/rec \
     Eval.dataset.label_file_list='[../label_studio/rec/new_val.txt]'
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/07/14 03:28:13] ppocr WARNING: Skipping import of the encryption module.
# [2025/07/14 03:28:13] ppocr INFO: Architecture :
# [2025/07/14 03:28:13] ppocr INFO:     Backbone :
# [2025/07/14 03:28:13] ppocr INFO:         name : PPLCNetV3
# [2025/07/14 03:28:13] ppocr INFO:         scale : 0.95
# [2025/07/14 03:28:13] ppocr INFO:     Head :
# [2025/07/14 03:28:13] ppocr INFO:         head_list :
# [2025/07/14 03:28:13] ppocr INFO:             CTCHead :
# [2025/07/14 03:28:13] ppocr INFO:                 Head :
# [2025/07/14 03:28:13] ppocr INFO:                     fc_decay : 1e-05
# [2025/07/14 03:28:13] ppocr INFO:                 Neck :
# ...

# %% [markdown]
# ## Export Finetuned Model

# %%
# !python tools/export_model.py -c configs/rec/PP-OCRv5/PP-OCRv5_mobile_rec.yml -o \
Global.pretrained_model=output/PP-OCRv5_mobile_rec/best_accuracy.pdparams \
Global.save_inference_dir="./finetuned_PP-OCRv5_mobile_rec_infer/"
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# [2025/07/14 03:31:04] ppocr WARNING: Skipping import of the encryption module.
# W0714 03:31:05.938936  3514 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.6, Driver API Version: 12.4, Runtime API Version: 11.8
# W0714 03:31:05.939872  3514 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# [2025/07/14 03:31:06] ppocr INFO: load pretrain successful from output/PP-OCRv5_mobile_rec/best_accuracy
# [2025/07/14 03:31:07] ppocr INFO: Export inference config file to ./finetuned_PP-OCRv5_mobile_rec_infer/inference.yml
# Skipping import of the encryption module
# ...
